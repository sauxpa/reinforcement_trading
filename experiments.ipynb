# %%
# !pip install -e gym-rl_trading/
# Out:
# Obtaining file:///home/sauxpa/github/reinforcement_trading/gym-rl_trading
# Requirement already satisfied: gym in /home/sauxpa/anaconda3/lib/python3.7/site-packages (from gym-rl-trading==0.0.1) (0.15.6)
# Requirement already satisfied: cloudpickle~=1.2.0 in /home/sauxpa/anaconda3/lib/python3.7/site-packages (from gym->gym-rl-trading==0.0.1) (1.2.2)
# Requirement already satisfied: numpy>=1.10.4 in /home/sauxpa/anaconda3/lib/python3.7/site-packages (from gym->gym-rl-trading==0.0.1) (1.17.2)
# Requirement already satisfied: six in /home/sauxpa/anaconda3/lib/python3.7/site-packages (from gym->gym-rl-trading==0.0.1) (1.12.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/sauxpa/anaconda3/lib/python3.7/site-packages (from gym->gym-rl-trading==0.0.1) (1.4.10)
# Requirement already satisfied: scipy in /home/sauxpa/anaconda3/lib/python3.7/site-packages (from gym->gym-rl-trading==0.0.1) (1.3.1)
# Requirement already satisfied: future in /home/sauxpa/anaconda3/lib/python3.7/site-packages (from pyglet<=1.5.0,>=1.4.0->gym->gym-rl-trading==0.0.1) (0.17.1)
# Installing collected packages: gym-rl-trading
#   Found existing installation: gym-rl-trading 0.0.1
#     Uninstalling gym-rl-trading-0.0.1:
#       Successfully uninstalled gym-rl-trading-0.0.1
#   Running setup.py develop for gym-rl-trading
# Successfully installed gym-rl-trading

# %%
import gym
import gym_rl_trading

# Autonomous Learning Library
# https://github.com/cpnota/autonomous-learning-library
from all.environments import GymEnvironment
from all.experiments import Experiment
from all.presets.classic_control import a2c

# %%
device = 'cpu'

# Brownian returns, no trend, no profit-making strategy.
env0 = GymEnvironment('rl_trading-v0', device=device)

# Brownian returns, +5% trend, profit-making long strategy.
env1 = GymEnvironment('rl_trading-v1', device=device)

# Brownian returns carried by a cyclical trend.
env2 = GymEnvironment('rl_trading-v2', device=device)

# Fractional Brownian, with local trend-following patterns.
env3 = GymEnvironment('rl_trading-v3', device=device)

# Fractional Brownian, with local mean-reversion patterns.
env4 = GymEnvironment('rl_trading-v4', device=device)

# Deterministic baseline with local trend-following patterns
env5 = GymEnvironment('rl_trading-v5', device=device)

# Deterministic baseline with local mean-reversion patterns
env6 = GymEnvironment('rl_trading-v6', device=device)

# Fractional Brownian, with local trend-following patterns.
# Observations are augmented vith the empirical autocorrelogram.
env7 = GymEnvironment('rl_trading-v7', device=device)

# Fractional Brownian, with local mean-reversion patterns.
# Observations are augmented vith the empirical autocorrelogram.
env8 = GymEnvironment('rl_trading-v8', device=device)
# Out:
# /home/sauxpa/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float64
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
### to view training results, run in a terminal:
# !tensorboard --logdir runs

# %%
episodes = 300
env = env5

Experiment(
    a2c(
        device=device, 
    ),
    env,
    episodes=episodes,
)
# Out:
# episode: 1, frames: 3980, fps: 1536, returns: -227
# episode: 2, frames: 3980, fps: 758, returns: -566
# episode: 3, frames: 3980, fps: 491, returns: 95
# episode: 4, frames: 3980, fps: 366, returns: 64
# episode: 5, frames: 7960, fps: 442, returns: -53
# episode: 6, frames: 7960, fps: 381, returns: -41
# episode: 7, frames: 7960, fps: 335, returns: 187
# episode: 8, frames: 7960, fps: 299, returns: -144
# episode: 9, frames: 11940, fps: 385, returns: -224
# episode: 10, frames: 11940, fps: 355, returns: -8
# episode: 11, frames: 11940, fps: 329, returns: 0
# episode: 12, frames: 11940, fps: 306, returns: -70
# episode: 13, frames: 15920, fps: 360, returns: 169
# episode: 14, frames: 15920, fps: 339, returns: 47
# episode: 15, frames: 15920, fps: 321, returns: -249
# episode: 16, frames: 15920, fps: 305, returns: 49
# episode: 17, frames: 19900, fps: 346, returns: 108
# episode: 18, frames: 19900, fps: 330, returns: -438
# episode: 19, frames: 19900, fps: 316, returns: -653
# episode: 20, frames: 19900, fps: 304, returns: -147
# episode: 21, frames: 23880, fps: 342, returns: -109
# episode: 22, frames: 23880, fps: 329, returns: -73
# episode: 23, frames: 23880, fps: 317, returns: -72
# episode: 24, frames: 23880, fps: 306, returns: -163
# episode: 25, frames: 27860, fps: 334, returns: 10
# episode: 26, frames: 27860, fps: 324, returns: -78
# episode: 27, frames: 27860, fps: 314, returns: -449
# episode: 28, frames: 27860, fps: 304, returns: -369
# episode: 29, frames: 31840, fps: 332, returns: -40
# episode: 30, frames: 31840, fps: 322, returns: -341
# episode: 31, frames: 31840, fps: 314, returns: -53
# episode: 32, frames: 31840, fps: 306, returns: -18
# episode: 33, frames: 35820, fps: 330, returns: -58
# episode: 34, frames: 35820, fps: 322, returns: -38
# episode: 35, frames: 35820, fps: 314, returns: -37
# episode: 36, frames: 35820, fps: 306, returns: -82
# episode: 37, frames: 39800, fps: 326, returns: -294
# episode: 38, frames: 39800, fps: 319, returns: -43
# episode: 39, frames: 39800, fps: 312, returns: 31
# episode: 40, frames: 39800, fps: 305, returns: -22
# episode: 41, frames: 43780, fps: 322, returns: -553
# episode: 42, frames: 43780, fps: 315, returns: -622
# episode: 43, frames: 43780, fps: 309, returns: -191
# episode: 44, frames: 43780, fps: 303, returns: 47
# episode: 45, frames: 47760, fps: 320, returns: -155
# episode: 46, frames: 47760, fps: 314, returns: 34
# episode: 47, frames: 47760, fps: 308, returns: 21
# episode: 48, frames: 47760, fps: 303, returns: -25
# episode: 49, frames: 51740, fps: 317, returns: -211
# episode: 50, frames: 51740, fps: 312, returns: 8
# episode: 51, frames: 51740, fps: 307, returns: -700
# episode: 52, frames: 51740, fps: 302, returns: 60
# episode: 53, frames: 55720, fps: 314, returns: 72
# episode: 54, frames: 55720, fps: 310, returns: -1406
# episode: 55, frames: 55720, fps: 305, returns: -19
# episode: 56, frames: 55720, fps: 301, returns: -168
# episode: 57, frames: 59700, fps: 313, returns: -684
# episode: 58, frames: 59700, fps: 309, returns: -411
# episode: 59, frames: 59700, fps: 304, returns: 72
# episode: 60, frames: 59700, fps: 300, returns: -32
# episode: 61, frames: 63680, fps: 313, returns: -39
# episode: 62, frames: 63680, fps: 308, returns: 18
# episode: 63, frames: 63680, fps: 305, returns: -176
# episode: 64, frames: 63680, fps: 301, returns: -30
# episode: 65, frames: 67660, fps: 312, returns: -251
# episode: 66, frames: 67660, fps: 308, returns: -22
# episode: 67, frames: 67660, fps: 304, returns: -806
# episode: 68, frames: 67660, fps: 300, returns: -55
# episode: 69, frames: 71640, fps: 312, returns: -3
# episode: 70, frames: 71640, fps: 308, returns: -242
# episode: 71, frames: 71640, fps: 304, returns: 25
# episode: 72, frames: 71640, fps: 301, returns: -303
# episode: 73, frames: 75620, fps: 311, returns: -191
# episode: 74, frames: 75620, fps: 307, returns: -208
# episode: 75, frames: 75620, fps: 304, returns: -951
# episode: 76, frames: 75620, fps: 301, returns: -518
# episode: 77, frames: 79600, fps: 310, returns: 78
# episode: 78, frames: 79600, fps: 306, returns: -695
# episode: 79, frames: 79600, fps: 303, returns: 24
# episode: 80, frames: 79600, fps: 300, returns: -59
# episode: 81, frames: 83580, fps: 309, returns: -5
# episode: 82, frames: 83580, fps: 306, returns: -146
# episode: 83, frames: 83580, fps: 303, returns: -61
# episode: 84, frames: 83580, fps: 300, returns: -41
# episode: 85, frames: 87560, fps: 308, returns: -10
# episode: 86, frames: 87560, fps: 305, returns: 187
# episode: 87, frames: 87560, fps: 302, returns: -191
# episode: 88, frames: 87560, fps: 299, returns: -296
# episode: 89, frames: 91540, fps: 308, returns: 18
# episode: 90, frames: 91540, fps: 305, returns: -12
# episode: 91, frames: 91540, fps: 303, returns: -662
# episode: 92, frames: 91540, fps: 300, returns: 2
# episode: 93, frames: 95520, fps: 308, returns: -61
# episode: 94, frames: 95520, fps: 305, returns: -213
# episode: 95, frames: 95520, fps: 302, returns: 6
# episode: 96, frames: 95520, fps: 300, returns: -111
# episode: 97, frames: 99500, fps: 308, returns: -61
# episode: 98, frames: 99500, fps: 305, returns: -22
# episode: 99, frames: 99500, fps: 303, returns: -255
# episode: 100, frames: 99500, fps: 300, returns: -40
# episode: 101, frames: 103480, fps: 307, returns: -74
# episode: 102, frames: 103480, fps: 304, returns: 29
# episode: 103, frames: 103480, fps: 302, returns: 107
# episode: 104, frames: 103480, fps: 300, returns: -119
# episode: 105, frames: 107460, fps: 306, returns: -1401
# episode: 106, frames: 107460, fps: 304, returns: -310
# episode: 107, frames: 107460, fps: 302, returns: -292
# episode: 108, frames: 107460, fps: 299, returns: -336
# episode: 109, frames: 111440, fps: 306, returns: -17
# episode: 110, frames: 111440, fps: 304, returns: -80
# episode: 111, frames: 111440, fps: 302, returns: -559
# episode: 112, frames: 111440, fps: 300, returns: -81
# episode: 113, frames: 115420, fps: 306, returns: 127
# episode: 114, frames: 115420, fps: 303, returns: -258
# episode: 115, frames: 115420, fps: 301, returns: 46
# episode: 116, frames: 115420, fps: 299, returns: -22
# episode: 117, frames: 119400, fps: 305, returns: 248
# episode: 118, frames: 119400, fps: 303, returns: -150
# episode: 119, frames: 119400, fps: 301, returns: -2
# episode: 120, frames: 119400, fps: 299, returns: -69
# episode: 121, frames: 123380, fps: 304, returns: 103
# episode: 122, frames: 123380, fps: 302, returns: 87
# episode: 123, frames: 123380, fps: 300, returns: 34
# episode: 124, frames: 123380, fps: 298, returns: -58
# episode: 125, frames: 127360, fps: 304, returns: -591
# episode: 126, frames: 127360, fps: 302, returns: 11
# episode: 127, frames: 127360, fps: 301, returns: -27
# episode: 128, frames: 127360, fps: 299, returns: 197
# episode: 129, frames: 131340, fps: 305, returns: 142
# episode: 130, frames: 131340, fps: 303, returns: -503
# episode: 131, frames: 131340, fps: 301, returns: -279
# episode: 132, frames: 131340, fps: 299, returns: -544
# episode: 133, frames: 135320, fps: 304, returns: -247
# episode: 134, frames: 135320, fps: 302, returns: 14
# episode: 135, frames: 135320, fps: 301, returns: 62
# episode: 136, frames: 135320, fps: 299, returns: -215
# episode: 137, frames: 139300, fps: 304, returns: -265
# episode: 138, frames: 139300, fps: 302, returns: 67
# episode: 139, frames: 139300, fps: 301, returns: -411
# episode: 140, frames: 139300, fps: 299, returns: -86
# episode: 141, frames: 143280, fps: 304, returns: -122
# episode: 142, frames: 143280, fps: 302, returns: 186
# episode: 143, frames: 143280, fps: 301, returns: -154
# episode: 144, frames: 143280, fps: 299, returns: -393
# episode: 145, frames: 147260, fps: 304, returns: 16
# episode: 146, frames: 147260, fps: 302, returns: 4
# episode: 147, frames: 147260, fps: 300, returns: -114
# episode: 148, frames: 147260, fps: 299, returns: 30
# episode: 149, frames: 151240, fps: 303, returns: 92
# episode: 150, frames: 151240, fps: 302, returns: -866
# episode: 151, frames: 151240, fps: 300, returns: 84
# episode: 152, frames: 151240, fps: 298, returns: -1375
# episode: 153, frames: 155220, fps: 303, returns: 7
# episode: 154, frames: 155220, fps: 301, returns: 36
# episode: 155, frames: 155220, fps: 300, returns: -165
# episode: 156, frames: 155220, fps: 297, returns: -376
# episode: 157, frames: 159200, fps: 302, returns: -331
# episode: 158, frames: 159200, fps: 300, returns: -61
# episode: 159, frames: 159200, fps: 298, returns: -2
# episode: 160, frames: 159200, fps: 297, returns: 7
# episode: 161, frames: 163180, fps: 302, returns: -244
# episode: 162, frames: 163180, fps: 300, returns: -124
# episode: 163, frames: 163180, fps: 299, returns: -45
# episode: 164, frames: 163180, fps: 298, returns: -141
# episode: 165, frames: 167160, fps: 303, returns: -140
# episode: 166, frames: 167160, fps: 302, returns: 48
# episode: 167, frames: 167160, fps: 300, returns: -6
# episode: 168, frames: 167160, fps: 299, returns: 15
# episode: 169, frames: 171140, fps: 303, returns: -186
# episode: 170, frames: 171140, fps: 302, returns: -445
# episode: 171, frames: 171140, fps: 301, returns: -141
# episode: 172, frames: 171140, fps: 300, returns: -197
# episode: 173, frames: 175120, fps: 304, returns: -175
# episode: 174, frames: 175120, fps: 303, returns: -1158
# episode: 175, frames: 175120, fps: 302, returns: -196
# episode: 176, frames: 175120, fps: 300, returns: -466
# episode: 177, frames: 179100, fps: 304, returns: -395
# episode: 178, frames: 179100, fps: 302, returns: -178
# episode: 179, frames: 179100, fps: 301, returns: 54
# episode: 180, frames: 179100, fps: 299, returns: 15
# episode: 181, frames: 183080, fps: 303, returns: -224
# episode: 182, frames: 183080, fps: 302, returns: 99
# episode: 183, frames: 183080, fps: 300, returns: 32
# episode: 184, frames: 183080, fps: 299, returns: -80
# episode: 185, frames: 187060, fps: 303, returns: -92
# episode: 186, frames: 187060, fps: 302, returns: -488
# episode: 187, frames: 187060, fps: 300, returns: 39
# episode: 188, frames: 187060, fps: 299, returns: 0
# episode: 189, frames: 191040, fps: 303, returns: -44
# episode: 190, frames: 191040, fps: 302, returns: 13
# episode: 191, frames: 191040, fps: 301, returns: -164
# episode: 192, frames: 191040, fps: 299, returns: -204
# episode: 193, frames: 195020, fps: 303, returns: 85
# episode: 194, frames: 195020, fps: 302, returns: 161
# episode: 195, frames: 195020, fps: 301, returns: -17
# episode: 196, frames: 195020, fps: 300, returns: -200
# episode: 197, frames: 199000, fps: 304, returns: -713
# episode: 198, frames: 199000, fps: 302, returns: -11
# episode: 199, frames: 199000, fps: 301, returns: -344
# episode: 200, frames: 199000, fps: 300, returns: 5
# episode: 201, frames: 202980, fps: 303, returns: 63
# episode: 202, frames: 202980, fps: 302, returns: -73
# episode: 203, frames: 202980, fps: 301, returns: -4
# episode: 204, frames: 202980, fps: 300, returns: -69
# episode: 205, frames: 206960, fps: 303, returns: 97
# episode: 206, frames: 206960, fps: 302, returns: -55
# episode: 207, frames: 206960, fps: 301, returns: -51
# episode: 208, frames: 206960, fps: 300, returns: 18
# episode: 209, frames: 210940, fps: 303, returns: -169
# episode: 210, frames: 210940, fps: 302, returns: -42
# episode: 211, frames: 210940, fps: 301, returns: 40
# episode: 212, frames: 210940, fps: 300, returns: -563
# episode: 213, frames: 214920, fps: 303, returns: -628
# episode: 214, frames: 214920, fps: 302, returns: -188
# episode: 215, frames: 214920, fps: 301, returns: -96
# episode: 216, frames: 214920, fps: 299, returns: -104
# episode: 217, frames: 218900, fps: 303, returns: 31
# episode: 218, frames: 218900, fps: 302, returns: -43
# episode: 219, frames: 218900, fps: 301, returns: -53
# episode: 220, frames: 218900, fps: 300, returns: 14
# episode: 221, frames: 222880, fps: 303, returns: -499
# episode: 222, frames: 222880, fps: 302, returns: 63
# episode: 223, frames: 222880, fps: 301, returns: -374
# episode: 224, frames: 222880, fps: 300, returns: -66
# episode: 225, frames: 226860, fps: 303, returns: -142
# episode: 226, frames: 226860, fps: 302, returns: -60
# episode: 227, frames: 226860, fps: 301, returns: -16
# episode: 228, frames: 226860, fps: 300, returns: -339
# episode: 229, frames: 230840, fps: 303, returns: -80
# episode: 230, frames: 230840, fps: 302, returns: 31
# episode: 231, frames: 230840, fps: 301, returns: -494
# episode: 232, frames: 230840, fps: 300, returns: -25
# episode: 233, frames: 234820, fps: 303, returns: -310
# episode: 234, frames: 234820, fps: 302, returns: -184
# episode: 235, frames: 234820, fps: 301, returns: -834
# episode: 236, frames: 234820, fps: 300, returns: 160
# episode: 237, frames: 238800, fps: 303, returns: 43
# episode: 238, frames: 238800, fps: 302, returns: 169
# episode: 239, frames: 238800, fps: 301, returns: -138
# episode: 240, frames: 238800, fps: 300, returns: 14
# episode: 241, frames: 242780, fps: 303, returns: 6
# episode: 242, frames: 242780, fps: 302, returns: 63
# episode: 243, frames: 242780, fps: 301, returns: -202
# episode: 244, frames: 242780, fps: 300, returns: -67
# episode: 245, frames: 246760, fps: 303, returns: -177
# episode: 246, frames: 246760, fps: 302, returns: -553
# episode: 247, frames: 246760, fps: 301, returns: 21
# episode: 248, frames: 246760, fps: 300, returns: -14
# episode: 249, frames: 250740, fps: 303, returns: -26
# episode: 250, frames: 250740, fps: 302, returns: -931
# episode: 251, frames: 250740, fps: 301, returns: -81
# episode: 252, frames: 250740, fps: 300, returns: 52
# episode: 253, frames: 254720, fps: 303, returns: -515
# episode: 254, frames: 254720, fps: 302, returns: -524
# episode: 255, frames: 254720, fps: 301, returns: -97
# episode: 256, frames: 254720, fps: 300, returns: -660
# episode: 257, frames: 258700, fps: 302, returns: -47
# episode: 258, frames: 258700, fps: 301, returns: 2
# episode: 259, frames: 258700, fps: 300, returns: 156
# episode: 260, frames: 258700, fps: 299, returns: -105
# episode: 261, frames: 262680, fps: 302, returns: -10
# episode: 262, frames: 262680, fps: 301, returns: -173
# episode: 263, frames: 262680, fps: 300, returns: -573
# episode: 264, frames: 262680, fps: 299, returns: -720
# episode: 265, frames: 266660, fps: 302, returns: 41
# episode: 266, frames: 266660, fps: 301, returns: -536
# episode: 267, frames: 266660, fps: 300, returns: -49
# episode: 268, frames: 266660, fps: 299, returns: -241
# episode: 269, frames: 270640, fps: 302, returns: -2
# episode: 270, frames: 270640, fps: 301, returns: -54
# episode: 271, frames: 270640, fps: 300, returns: 0
# episode: 272, frames: 270640, fps: 299, returns: 58
# episode: 273, frames: 274620, fps: 302, returns: -218
# episode: 274, frames: 274620, fps: 301, returns: -11
# episode: 275, frames: 274620, fps: 300, returns: 34
# episode: 276, frames: 274620, fps: 299, returns: -310
# episode: 277, frames: 278600, fps: 301, returns: 178
# episode: 278, frames: 278600, fps: 300, returns: -48
# episode: 279, frames: 278600, fps: 300, returns: 95
# episode: 280, frames: 278600, fps: 299, returns: 161
# episode: 281, frames: 282580, fps: 301, returns: 161
# episode: 282, frames: 282580, fps: 300, returns: -82
# episode: 283, frames: 282580, fps: 299, returns: -6
# episode: 284, frames: 282580, fps: 298, returns: -675
# episode: 285, frames: 286560, fps: 301, returns: -325
# episode: 286, frames: 286560, fps: 300, returns: -80
# episode: 287, frames: 286560, fps: 299, returns: 126
# episode: 288, frames: 286560, fps: 299, returns: -493
# episode: 289, frames: 290540, fps: 301, returns: 352
# episode: 290, frames: 290540, fps: 300, returns: -40
# episode: 291, frames: 290540, fps: 299, returns: -76
# episode: 292, frames: 290540, fps: 298, returns: -7
# episode: 293, frames: 294520, fps: 301, returns: -724
# episode: 294, frames: 294520, fps: 300, returns: 81
# episode: 295, frames: 294520, fps: 299, returns: -279
# episode: 296, frames: 294520, fps: 298, returns: -110
# episode: 297, frames: 298500, fps: 300, returns: 120
# episode: 298, frames: 298500, fps: 300, returns: 136
# episode: 299, frames: 298500, fps: 299, returns: 9
# episode: 300, frames: 298500, fps: 298, returns: -568
